# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
initial_tabulated_data = pd.read_csv("dataverse_files/HAM10000_metadata")

initial_tabulated_data.head(20)
# Out:
#       lesion_id      image_id   dx dx_type   age     sex     localization  \
# 0   HAM_0000118  ISIC_0027419  bkl   histo  80.0    male            scalp
# 1   HAM_0000118  ISIC_0025030  bkl   histo  80.0    male            scalp
# 2   HAM_0002730  ISIC_0026769  bkl   histo  80.0    male            scalp
# 3   HAM_0002730  ISIC_0025661  bkl   histo  80.0    male            scalp
# 4   HAM_0001466  ISIC_0031633  bkl   histo  75.0    male              ear
# 5   HAM_0001466  ISIC_0027850  bkl   histo  75.0    male              ear
# 6   HAM_0002761  ISIC_0029176  bkl   histo  60.0    male             face
# 7   HAM_0002761  ISIC_0029068  bkl   histo  60.0    male             face
# 8   HAM_0005132  ISIC_0025837  bkl   histo  70.0  female             back
# 9   HAM_0005132  ISIC_0025209  bkl   histo  70.0  female             back
# 10  HAM_0001396  ISIC_0025276  bkl   histo  55.0  female            trunk
# 11  HAM_0004234  ISIC_0029396  bkl   histo  85.0  female            chest
# ...

# %%
clm_names = initial_tabulated_data.columns.values

for clm_name in clm_names:
    print("{}".format(clm_name))
    print(initial_tabulated_data[clm_name].unique())
# Out:
# lesion_id
# ['HAM_0000118' 'HAM_0002730' 'HAM_0001466' ... 'HAM_0005579' 'HAM_0001576'
#  'HAM_0002867']
# image_id
# ['ISIC_0027419' 'ISIC_0025030' 'ISIC_0026769' ... 'ISIC_0033536'
#  'ISIC_0032854' 'ISIC_0032258']
# dx
# ['bkl' 'nv' 'df' 'mel' 'vasc' 'bcc' 'akiec']
# dx_type
# ['histo' 'consensus' 'confocal' 'follow_up']
# age
# [80. 75. 60. 70. 55. 85. 65. 40. 50. 45. 35.  0. 30. nan  5. 25. 20. 10.
#  15.]
# sex
# ['male' 'female' 'unknown']
# localization
# ['scalp' 'ear' 'face' 'back' 'trunk' 'chest' 'upper extremity' 'abdomen'
#  'unknown' 'lower extremity' 'genital' 'neck' 'hand' 'foot' 'acral']
# dataset
# ['vidir_modern' 'rosendahl' 'vienna_dias' 'vidir_molemax']

# %%
goal_one_data_set = initial_tabulated_data.copy()[["lesion_id","image_id","dx"]]
goal_one_data_set.head(15)

# %%
goal_one_data_set.sort_values(by="lesion_id",axis=0,inplace=True)
goal_one_data_set.head()
# Out:
#         lesion_id      image_id   dx
# 9187  HAM_0000000  ISIC_0028498   nv
# 9188  HAM_0000000  ISIC_0025346   nv
# 726   HAM_0000001  ISIC_0027859  bkl
# 1661  HAM_0000002  ISIC_0032622  mel
# 1660  HAM_0000002  ISIC_0033848  mel

# %%
goal_one_data_set.to_csv("Goal 1/trimmed_dataset.csv")
